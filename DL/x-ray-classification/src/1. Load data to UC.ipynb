# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia

# %%
# curl -L \
#   "https://www.kaggle.com/api/v1/datasets/download/paultimothymooney/chest-xray-pneumonia" \
#   --output /Volumes/users/kevin_romero/kaggle/x-ray-kaggle/chest-xray-pneumonia.zip

# unzip /Volumes/users/kevin_romero/kaggle/x-ray-kaggle/chest-xray-pneumonia.zip \
#   -d /Volumes/users/kevin_romero/kaggle/x-ray-kaggle/chest-xray-pneumonia
